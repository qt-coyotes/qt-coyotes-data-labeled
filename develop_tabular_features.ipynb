# %%
import json

# %%
with open("data/processed/qt-coyotes-merged.json") as f:
    coco = json.load(f)

# %%
len(coco["images"])
# Out:
# 16050

# %%
len(list(map(lambda image: image["datetime"], coco["images"])))
# Out:
# 16050

# %%
set(map(lambda image: image["location"], coco["images"]))
# Out:
# {'39th st east',
#  '39th st west',
#  'ADC',
#  'ASC',
#  'All Saints Cemetery',
#  'Argonne',
#  'BEC',
#  'BLW',
#  'BON',
#  'Beck Lake',
#  'Belleau Woods',
#  'Big Marsh (Bike Park)',
#  'Brighton Park',
#  'Brooks Park',
#  'Burnham - 47th St NS',
#  'Burnham Bird Sanctuary',
#  'CAN',
#  'CBW',
#  'CCC',
#  'CLG',
#  'CPG',
#  'CPR',
#  'CTG',
#  'Canoe Launch 1',
#  'Cantigny Park and Golf Club',
#  'Chevy Chase Country Club',
#  'Chopin Park',
#  'Columbia Woods',
#  'Columbus Park golf course',
#  "Crane''s Landing GC",
#  'Cumberland::A',
#  'Cumberland::B',
#  'DAP',
#  'DAW',
#  'Dam No. 1 Woods',
#  'Dam no. 1 woods',
#  'Danby Park',
#  'Dunham Park',
#  'EDW',
#  'Edgebrook Volunteer Center',
#  'Edgebrook Woods',
#  'FRM',
#  'FSP',
#  'Falconer::A',
#  'Falconer::B',
#  'Fermi',
#  'Four Seasons Park',
#  'Fresh Meadow Golf',
#  'GOC',
#  'GOF',
#  'Glen Oak Cemetery',
#  'Glen Oak Forest Preserve',
#  'Gompers Park',
#  'Hegewisch Marsh',
#  'Humboldt Park',
# ...
